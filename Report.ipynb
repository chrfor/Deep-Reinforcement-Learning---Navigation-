# %% [raw]
# >>>Learning Algorithm
#
#
# >The learning algorithm which have been used in this implementation is Deep Q network from the exercice in the Deep QNetwork lesson.
# >The hyperparameters have been kept as in the Deep Q Network Lesson except the buffer replay has been extended to from 1e5 to 1e6.
#
# BUFFER_SIZE = int(1e6)  # replay buffer size
# BATCH_SIZE = 64         # minibatch size
# GAMMA = 0.99            # discount factor
# TAU = 1e-3              # for soft update of target parameters
# LR = 5e-4               # learning rate
# UPDATE_EVERY = 4        # how often to update the network
# First fully connected layer 64 units
# Second fully connected layer 64 units
#
#
#
# >>>Plot of Rewards
#
# The environment has been solved at Episode 600 with an Average Score: 13.21
# Episode 100	Average Score: 0.93
# Episode 200	Average Score: 4.89
# Episode 300	Average Score: 8.11
# Episode 400	Average Score: 10.82
# Episode 500	Average Score: 12.01
# Episode 600	Average Score: 13.21
# Episode 700	Average Score: 14.19
# Episode 800	Average Score: 13.80
# Episode 900	Average Score: 14.26
# Episode 1000	Average Score: 15.25
# Episode 1100	Average Score: 14.27
# Episode 1200	Average Score: 14.93
# Episode 1300	Average Score: 14.84
# Episode 1400	Average Score: 15.65
# Episode 1500	Average Score: 15.56
# Episode 1600	Average Score: 15.49
# Episode 1700	Average Score: 14.44
# Episode 1800	Average Score: 14.66
# Episode 1900	Average Score: 14.72
# Episode 1936	Average Score: 14.36
#
#
# Episode 100	Average Score: 1.05
# Episode 200	Average Score: 5.18
# Episode 300	Average Score: 8.39
# Episode 400	Average Score: 9.81
# Episode 500	Average Score: 12.38
# Episode 600	Average Score: 13.42
# Episode 700	Average Score: 13.86
# Episode 800	Average Score: 13.74
# Episode 900	Average Score: 14.22
# Episode 1000	Average Score: 13.71
# Out[6]:
# Text(0.5,0,'Episode #')
#
#
#
#
#
#
#
# >>>Ideas for Future Work
# >To finalize the implementation of Dueling Network which have been implemented but without success(see the Model file)
#
#
# >To implement the pieces of advices from Mentor :
# - To add in the experience buffer not all but the (S,A,R,S,Q) value where reward is above a certain threshold.
# - Changing after how many time steps the Target Q-network is updated also influences the stability of Q-Network.
#
#
# >To implement the Rainbow and build a powerful agent
# -Double DQN (DDQN)
# -Prioritized experience replay
# -Dueling DQN
# -Learning from multi-step bootstrap targets
# -Distributional DQN
# -Noisy DQN
